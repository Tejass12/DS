# %%
import numpy as np

import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %%
df=pd.read_csv("iris.csv")

# %% [markdown]
# importing iris dataset

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.size
# Out:
# 750

# %%
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.columns.values
# Out:
# array(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'], dtype=object)

# %%
df.columns.values.tolist()
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
display(df.loc[2: 5])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
display(df.iloc[2:7])
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
df.iloc[5:6,3:5]
# Out:
#    petal_width species
# 5          0.4  setosa

# %%
df.iloc[5:,3:5]
# Out:
#      petal_width    species
# 5            0.4     setosa
# 6            0.3     setosa
# 7            0.2     setosa
# 8            0.2     setosa
# 9            0.1     setosa
# ..           ...        ...
# 145          2.3  virginica
# 146          1.9  virginica
# 147          2.0  virginica
# 148          2.3  virginica
# 149          1.8  virginica
#
# [145 rows x 2 columns]

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.isnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.notnull()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0            True         True          True         True     True
# 1            True         True          True         True     True
# 2            True         True          True         True     True
# 3            True         True          True         True     True
# 4            True         True          True         True     True
# ..            ...          ...           ...          ...      ...
# 145          True         True          True         True     True
# 146          True         True          True         True     True
# 147          True         True          True         True     True
# 148          True         True          True         True     True
# 149          True         True          True         True     True
#
# [150 rows x 5 columns]

# %%
df.notnull().sum()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.fillna(0)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12240\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12240\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# sepal_length    5.80
# sepal_width     3.00
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %% [markdown]
# df.mode()

# %% [markdown]
# df.mode()

# %%
df.mode()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width     species
# 0           5.0          3.0           1.5          0.2      setosa
# 1           NaN          NaN           NaN          NaN  versicolor
# 2           NaN          NaN           NaN          NaN   virginica

# %%
df.rename(columns = {'sepal_length':'sp_l'})
# Out:
#      sp_l  sepal_width  petal_length  petal_width    species
# 0     5.1          3.5           1.4          0.2     setosa
# 1     4.9          3.0           1.4          0.2     setosa
# 2     4.7          3.2           1.3          0.2     setosa
# 3     4.6          3.1           1.5          0.2     setosa
# 4     5.0          3.6           1.4          0.2     setosa
# ..    ...          ...           ...          ...        ...
# 145   6.7          3.0           5.2          2.3  virginica
# 146   6.3          2.5           5.0          1.9  virginica
# 147   6.5          3.0           5.2          2.0  virginica
# 148   6.2          3.4           5.4          2.3  virginica
# 149   5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['sepal_length']=df['sepal_length'].astype('int')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0               5          3.5           1.4          0.2     setosa
# 1               4          3.0           1.4          0.2     setosa
# 2               4          3.2           1.3          0.2     setosa
# 3               4          3.1           1.5          0.2     setosa
# 4               5          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145             6          3.0           5.2          2.3  virginica
# 146             6          2.5           5.0          1.9  virginica
# 147             6          3.0           5.2          2.0  virginica
# 148             6          3.4           5.4          2.3  virginica
# 149             5          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df['species']=df['species'].str.upper()

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0               5          3.5           1.4          0.2     SETOSA
# 1               4          3.0           1.4          0.2     SETOSA
# 2               4          3.2           1.3          0.2     SETOSA
# 3               4          3.1           1.5          0.2     SETOSA
# 4               5          3.6           1.4          0.2     SETOSA
# ..            ...          ...           ...          ...        ...
# 145             6          3.0           5.2          2.3  VIRGINICA
# 146             6          2.5           5.0          1.9  VIRGINICA
# 147             6          3.0           5.2          2.0  VIRGINICA
# 148             6          3.4           5.4          2.3  VIRGINICA
# 149             5          3.0           5.1          1.8  VIRGINICA
#
# [150 rows x 5 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0               5          3.5           1.4          0.2     SETOSA
# 1               4          3.0           1.4          0.2     SETOSA
# 2               4          3.2           1.3          0.2     SETOSA
# 3               4          3.1           1.5          0.2     SETOSA
# 4               5          3.6           1.4          0.2     SETOSA
# ..            ...          ...           ...          ...        ...
# 145             6          3.0           5.2          2.3  VIRGINICA
# 146             6          2.5           5.0          1.9  VIRGINICA
# 147             6          3.0           5.2          2.0  VIRGINICA
# 148             6          3.4           5.4          2.3  VIRGINICA
# 149             5          3.0           5.1          1.8  VIRGINICA
#
# [142 rows x 5 columns]

# %%
scaler=MinMaxScaler()
df[['sepal_length','sepal_width']]=scaler.fit_transform(df[['sepal_length','sepal_width']])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        0.333333     0.625000           1.4          0.2     SETOSA
# 1        0.000000     0.416667           1.4          0.2     SETOSA
# 2        0.000000     0.500000           1.3          0.2     SETOSA
# 3        0.000000     0.458333           1.5          0.2     SETOSA
# 4        0.333333     0.666667           1.4          0.2     SETOSA
# ..            ...          ...           ...          ...        ...
# 145      0.666667     0.416667           5.2          2.3  VIRGINICA
# 146      0.666667     0.208333           5.0          1.9  VIRGINICA
# 147      0.666667     0.416667           5.2          2.0  VIRGINICA
# 148      0.666667     0.583333           5.4          2.3  VIRGINICA
# 149      0.333333     0.416667           5.1          1.8  VIRGINICA
#
# [142 rows x 5 columns]

# %%
scaler=StandardScaler()
df[['sepal_length','sepal_width']]=scaler.fit_transform(df[['sepal_length','sepal_width']])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0       -0.506948     1.028004           1.4          0.2     SETOSA
# 1       -1.706724    -0.112438           1.4          0.2     SETOSA
# 2       -1.706724     0.343739           1.3          0.2     SETOSA
# 3       -1.706724     0.115650           1.5          0.2     SETOSA
# 4       -0.506948     1.256092           1.4          0.2     SETOSA
# ..            ...          ...           ...          ...        ...
# 145      0.692829    -0.112438           5.2          2.3  VIRGINICA
# 146      0.692829    -1.252880           5.0          1.9  VIRGINICA
# 147      0.692829    -0.112438           5.2          2.0  VIRGINICA
# 148      0.692829     0.799916           5.4          2.3  VIRGINICA
# 149     -0.506948    -0.112438           5.1          1.8  VIRGINICA
#
# [142 rows x 5 columns]

# %%
scaler=StandardScaler()
df[['petal_length','petal_width']]=scaler.fit_transform(df[['petal_length','petal_width']])

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0       -0.506948     1.028004     -1.384549    -1.363246     SETOSA
# 1       -1.706724    -0.112438     -1.384549    -1.363246     SETOSA
# 2       -1.706724     0.343739     -1.441736    -1.363246     SETOSA
# 3       -1.706724     0.115650     -1.327363    -1.363246     SETOSA
# 4       -0.506948     1.256092     -1.384549    -1.363246     SETOSA
# ..            ...          ...           ...          ...        ...
# 145      0.692829    -0.112438      0.788525     1.423046  VIRGINICA
# 146      0.692829    -1.252880      0.674152     0.892323  VIRGINICA
# 147      0.692829    -0.112438      0.788525     1.025004  VIRGINICA
# 148      0.692829     0.799916      0.902897     1.423046  VIRGINICA
# 149     -0.506948    -0.112438      0.731339     0.759643  VIRGINICA
#
# [142 rows x 5 columns]

# %%
df['species'].replace(['setosa','versicolor​  ','virginica'],[0,1,-1])
# Out:
# 0         SETOSA
# 1         SETOSA
# 2         SETOSA
# 3         SETOSA
# 4         SETOSA
#          ...
# 145    VIRGINICA
# 146    VIRGINICA
# 147    VIRGINICA
# 148    VIRGINICA
# 149    VIRGINICA
# Name: species, Length: 142, dtype: object

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0       -0.506948     1.028004     -1.384549    -1.363246     SETOSA
# 1       -1.706724    -0.112438     -1.384549    -1.363246     SETOSA
# 2       -1.706724     0.343739     -1.441736    -1.363246     SETOSA
# 3       -1.706724     0.115650     -1.327363    -1.363246     SETOSA
# 4       -0.506948     1.256092     -1.384549    -1.363246     SETOSA
# ..            ...          ...           ...          ...        ...
# 145      0.692829    -0.112438      0.788525     1.423046  VIRGINICA
# 146      0.692829    -1.252880      0.674152     0.892323  VIRGINICA
# 147      0.692829    -0.112438      0.788525     1.025004  VIRGINICA
# 148      0.692829     0.799916      0.902897     1.423046  VIRGINICA
# 149     -0.506948    -0.112438      0.731339     0.759643  VIRGINICA
#
# [142 rows x 5 columns]

# %%
species = [['SENTOSA'],['VIRGINICA'],['VEERSICOLOR']]
df = pd.DataFrame(species)
df_encoded = pd.get_dummies(df['species'])
print(df_encoded)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [107], in <cell line: 3>()
#       1 species = [['SENTOSA'],['VIRGINICA'],['VEERSICOLOR']]
#       2 df = pd.DataFrame(species)
# ----> 3 df_encoded = pd.get_dummies(df['species'])
#       4 print(df_encoded)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'species'
